# %%
#亂數猜數字
import random

min = 1
max = 2
count = 0
guess_value = random.randint(min,max) # 建立1～100的亂數
print("========猜數字遊戲========\n")

while(True):
    keyin = int(input(f"猜數字範圍{min}~{max}"))
    count += 1
    if keyin >= min and keyin <= max:
        if (keyin == guess_value):
            print(f"🎉賓果!猜對了!!!答案是{guess_value}")
            print(f"  您猜了{count}次")
            break
        elif keyin > guess_value:
            print("再小一點!")
            max = keyin - 1
            
        elif keyin < guess_value:
            print("再大一點")
            min = keyin + 1

        else:
            max == min and guess_value == max
            print(f"🤧您失敗了,答案是{guess_value}")
           
        print(f"  您已經猜了{count}次")

            
    else:
        print("請輸入提示範圍數字")

print("\n～遊戲結束～")
# Out:
# ========猜數字遊戲========
#
# 再大一點
#   您已經猜了1次
# 🎉賓果!猜對了!!!答案是2
#   您猜了2次
#
# ～遊戲結束～
