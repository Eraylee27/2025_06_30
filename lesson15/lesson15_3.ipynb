# %%
#1家分店30天營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([9692, 7309, 9519, 5056, 1025, 9237, 4329, 3026, 5236,  155, 1901,
#        4824, 2866, 2155, 6266, 2478, 5524, 4206, 3915, 1288, 6834, 5081,
#         154, 7617, 4562, 6927, 2298, 3485, 1593,  196], dtype=int32)

# %%
#累計每天這家店的營收
one_store_cum = one_store.cumsum()
one_store_cum
# Out:
# array([  9692,  17001,  26520,  31576,  32601,  41838,  46167,  49193,
#         54429,  54584,  56485,  61309,  64175,  66330,  72596,  75074,
#         80598,  84804,  88719,  90007,  96841, 101922, 102076, 109693,
#        114255, 121182, 123480, 126965, 128558, 128754])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), one_store_cum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
