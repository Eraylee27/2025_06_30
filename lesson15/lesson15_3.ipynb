# %%
#1家分店30天營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([3394, 1916, 5680,  401,  222, 5346, 4841, 6275, 9593, 3077, 5743,
#        6908, 6648, 5891,  315, 9105, 7761, 1734, 9138, 8012, 5564, 3483,
#        1302, 8160, 6838, 9198, 8989, 1727, 5185, 1159], dtype=int32)

# %%
#累計每天這家店的營收
one_store_cum = one_store.cumsum()
one_store_cum
# Out:
# array([  3394,   5310,  10990,  11391,  11613,  16959,  21800,  28075,
#         37668,  40745,  46488,  53396,  60044,  65935,  66250,  75355,
#         83116,  84850,  93988, 102000, 107564, 111047, 112349, 120509,
#        127347, 136545, 145534, 147261, 152446, 153605])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), one_store_cum, marker='o', linestyle='-', color='b', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
